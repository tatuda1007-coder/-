# %% [markdown]
# <a href="https://colab.research.google.com/github/tatuda1007-coder/-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x=np.array([1 ,2])
y=np.array([3 ,4])
print("x=",x)
print("y=",y)
print("x+y=",x+y)
print("x・y=",np.dot(x ,y))
# Out:
# x= [1 2]
# y= [3 4]
# x+y= [4 6]
# x・y= 11
