# %% [markdown]
# <a href="https://colab.research.google.com/github/tatuda1007-coder/math/blob/main/python_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=3
b=4
print(a+b)
# Out:
# 7

# %%
a = 3
b = 6
print(a*b)
# Out:
# 18

# %%
a = 6
b = 10
print(a/b)
print(a//b)
print(a%b)
# Out:
# 0.6
# 0
# 6
